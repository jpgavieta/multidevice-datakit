# %% [markdown]
# # Atmotube Device Report
#
#
# This notebook demonstrates how to analyze data from multiple devices of the following type/s: Atmotube.

# %% [markdown]
# ## Load the Data

# %%
import sys
sys.path.insert(0, "..") # run at repo root

from contextlib import redirect_stdout # just to supress the mount data output so its less messy
import os
import warnings
warnings.filterwarnings('ignore')

from src.etl.load import load


MOUNT_PATH = "/home/yul/mnt/proton-data"

with redirect_stdout(open(os.devnull, 'w')): # supress the output, comment out and just run `data = load_data(MOUNT_PATH)` to debug if the pipeline fails
    data = load(MOUNT_PATH)

# %%
from src.utils import skim

skim(data)

# %%
d1 = data["Atmotube"]["C3CBE16AE294_01-May-2026_12-Jun-2026"]
d2 = data["Atmotube"]["C7A595F09965_01-May-2026_12-Jun-2026"]
d3 = data["Atmotube"]["CC6A51B6DC90_01-May-2026_12-Jun-2026"]
d4 = data["Atmotube"]["DB7A737B8CA0_01-May-2026_12-Jun-2026"]
d5 = data["Atmotube"]["E53CDF6B7FD3_01-May-2026_12-Jun-2026"]
d6 = data["Atmotube"]["E9F716D1DF7B_01-May-2026_12-Jun-2026"]
d7 = data["Atmotube"]["FD20113AFE41_01-May-2026_12-Jun-2026"]

# list(d1["data"].keys()) # Shows a list of the variables of one device

for i, d in enumerate([d1, d2, d3, d4, d5, d6, d7], start=1): # Shows a list of variables for all selected devices
    print(f"d{i}: {list(d['data'].keys())}")

# %% [markdown]
# ## Summarize Data Loss
#
# How much coverage does each variable have in the total dataset per device?

# %%
from src.stats import report_loss

# report_loss(d1) # Show data loss report for one device

for i, d in enumerate([d1, d2, d3, d4, d5, d6, d7], start=1):
    print(f"=== d{i} ===")
    report_loss(d)

# %% [markdown]
# ## Profile Dataframes

# %%
print(d1["all"].shape)
print(d1["all"].columns)
print(d1["all"].info())

# %% [markdown]
# #
