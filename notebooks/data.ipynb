# %% [markdown]
# # MultiDevice Data Usage
#
# This notebook explains how to use this repo's multidevice etl pipeline, and then how to use the processed data to view and retrieve for each device (`device_type`, `device_id`), its dataframes (`df`); and each df's variables (AKA columns).

# %% [markdown]
# ## Load All Data
#
# The function `load_data()` automatically triggers the etl (extract, transform, load) pipeline to prepare all available device data for analysis.
# This is the one-liner command to load everything.
#
# **Note**: This pipeline is currently extracts from a mounted Proton Drive folder, it can be upgraded to API calls per `device_id` instead.

# %%
import sys
sys.path.insert(0, "..") # run at repo root

from src.etl.load import load

MOUNT_PATH = "/home/yul/mnt/proton-data"

data = load(MOUNT_PATH)
# Out:
# --- Scanning: /home/yul/mnt/proton-data ---
# Processing folder: Atmotube
#    ✅ Loaded C3CBE16AE294_01-May-2026_12-Jun-2026: (18241, 22)
#    ✅ Loaded C7A595F09965_01-May-2026_12-Jun-2026: (11817, 22)
#    ✅ Loaded CC6A51B6DC90_01-May-2026_12-Jun-2026: (12068, 22)
#    ✅ Loaded DB7A737B8CA0_01-May-2026_12-Jun-2026: (17253, 22)
#    ✅ Loaded E53CDF6B7FD3_01-May-2026_12-Jun-2026: (12250, 22)
#    ✅ Loaded E9F716D1DF7B_01-May-2026_12-Jun-2026: (24095, 22)
#    ✅ Loaded FD20113AFE41_01-May-2026_12-Jun-2026: (12990, 22)
#   ✅ Atmotube: 7 device_id(s) loaded
# Processing folder: Fitbit
#   ⚠️ Fitbit: No valid CSVs loaded
# Processing folder: Ponyopi
#   ⚠️ Ponyopi: No valid CSVs loaded
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/C3CBE16AE294_01-May-2026_12-Jun-2026
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/C7A595F09965_01-May-2026_12-Jun-2026
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/CC6A51B6DC90_01-May-2026_12-Jun-2026
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/DB7A737B8CA0_01-May-2026_12-Jun-2026
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/E53CDF6B7FD3_01-May-2026_12-Jun-2026
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/E9F716D1DF7B_01-May-2026_12-Jun-2026
# Detected datetime column: 'Date (UTC+05:30)' (score: 5.00) → renamed to 'datetime'
# Detected lat column: 'Latitude' → renamed to 'latitude'
# Detected lon column: 'Longitude' → renamed to 'longitude'
# No raw particle count data available.
# No satellite data available.
# ✅ Transformed Atmotube/FD20113AFE41_01-May-2026_12-Jun-2026

# %%
# See which device types are available 
list_device_types = data.keys() 
print(list_device_types)

# See available device IDs, per type
list_device_ids = data["Atmotube"].keys()
print(list_device_ids)
# Out:
# dict_keys(['Atmotube'])
# dict_keys(['C3CBE16AE294_01-May-2026_12-Jun-2026', 'C7A595F09965_01-May-2026_12-Jun-2026', 'CC6A51B6DC90_01-May-2026_12-Jun-2026', 'DB7A737B8CA0_01-May-2026_12-Jun-2026', 'E53CDF6B7FD3_01-May-2026_12-Jun-2026', 'E9F716D1DF7B_01-May-2026_12-Jun-2026', 'FD20113AFE41_01-May-2026_12-Jun-2026'])

# %%
# Alternatively, this is how to extract the raw, unprocessed data
from src.etl.extract import extract_raw_data

raw = extract_raw_data("/home/yul/mnt/proton-data")
raw["Atmotube"]["C3CBE16AE294_01-May-2026_12-Jun-2026"]  # example

# %% [markdown]
# ## See Available Devices
#
# For each device type (`device_type`), the actual devices are indexed according to its device ID (`device_id`).
#
# The function `skim()` quickly shows the available dataframes (`df`) per actual device (`device_id`).
# It can accept one or a list of `device_type`, `device_id`, `df`, and columns, each.
#
# It returns, per each available device, its shape (columns nos. and rows nos.) and range (start datetime to end datetime).

# %%
from src.utils import skim

# a. View ALL of the loaded data, devices, and device types
# skim(data) 

# b. View loaded data by device type
# print("=== Per Type ===")
# skim(data, "Atmotube")                
# skim(data, ["Atmotube", "Fitbit"])     

# c. View loaded data by device ID
print("=== PER DEVICE ===")
# skim(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026") 
skim (data, "Atmotube", ["C7A595F09965_01-May-2026_12-Jun-2026", 
                        "FD20113AFE41_01-May-2026_12-Jun-2026"]
                        )


# (equivalent manual version, for comparison:)
# display_loaded_data({"Atmotube": {"C3CBE16AE294_01-May-2026_12-Jun-2026": data["Atmotube"]["C3CBE16AE294_01-May-2026_12-Jun-2026"]}})
# Out:
# === PER DEVICE ===
# Atmotube/C7A595F09965_01-May-2026_12-Jun-2026
#   dfs : ['gis', 'pm', 'weather', 'gas', 'phone', 'sat', 'txt']
#   gis       : (11817, 5)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   pm        : (11817, 4)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   weather   : (11817, 5)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   gas       : (11817, 5)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   phone     : (11817, 6)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   sat       : (11817, 2)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   txt       : (11817, 2)  |  2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#
# Atmotube/FD20113AFE41_01-May-2026_12-Jun-2026
#   dfs : ['gis', 'pm', 'weather', 'gas', 'phone', 'sat', 'txt']
#   gis       : (12990, 5)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00
#   pm        : (12990, 4)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00
#   weather   : (12990, 5)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00
#   gas       : (12990, 5)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00
#   phone     : (12990, 6)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00
#   sat       : (12990, 2)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00
#   txt       : (12990, 2)  |  2026-05-30 17:54:00+00:00 → 2026-06-12 15:59:00+00:00

# %% [markdown]
# When `skim()` used to inspect one or more `df`, it returns its available variables' (AKA columns) row length and data type (AKA dtype).

# %%
from src.utils import skim

# d. View loaded data by dataframe
print("=== PER DATAFRAME ===")
# skim(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", "pm")
skim(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", ["pm", "weather"])

print("")
# e. View loaded data by variable
print("=== PER VARIABLE ===")
# skim(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", "pm", "pm10_ugm3_atm")
skim(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", "pm", ["pm2_5_ugm3_atm", "pm10_ugm3_atm"])
# Out:
# === PER DATAFRAME ===
# Atmotube/C7A595F09965_01-May-2026_12-Jun-2026/pm
#   df.shape: (11817, 4)
#   range   : 2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   datetime                 : (11817, datetime64[ns, UTC])
#   pm1_0_ugm3_atm           : (11817, float64)
#   pm2_5_ugm3_atm           : (11817, float64)
#   pm10_ugm3_atm            : (11817, float64)
# Atmotube/C7A595F09965_01-May-2026_12-Jun-2026/weather
#   df.shape: (11817, 5)
#   range   : 2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00
#   datetime                 : (11817, datetime64[ns, UTC])
#   aqs_total                : (11817, Int64)
#   temp_c                   : (11817, float64)
#   hum_pct                  : (11817, float64)
#   press_hpa                : (11817, float64)
#
# === PER VARIABLE ===
# Atmotube/C7A595F09965_01-May-2026_12-Jun-2026/pm/pm2_5_ugm3_atm
#   (11817, float64)
#   range   : 2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00  (where 'pm2_5_ugm3_atm' is present)
# Atmotube/C7A595F09965_01-May-2026_12-Jun-2026/pm/pm10_ugm3_atm
#   (11817, float64)
#   range   : 2026-05-30 14:57:00+00:00 → 2026-06-12 15:56:00+00:00  (where 'pm10_ugm3_atm' is present)

# %% [markdown]
# ### Structural Relationship of the Data
#
# Below represents the structural hierarchical relationship between the data based on device type, devices, and each device's dataframes and their variables.
#
# They are all retrievable as a dictionary of each other.

# %%
import json

# Structure of the entire data hierarchy
print("Available Device Types:")
print(json.dumps({k: type(v).__name__ for k, v in data.items()}, indent=2))

print("\nDevices in Atmotube:")
print(json.dumps({k: type(v).__name__ for k, v in data["Atmotube"].items()}, indent=2))

from src.utils import get
device = get(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026")

print("\nStructure of One Device:")
print(json.dumps({k: type(v).__name__ for k, v in device.items()}, indent=2))

# %% [markdown]
# ## Retrieve Device Data
#
# Since any device and its contents are all kept as nested dictionaries.
#
# The function `get()` can navigate and retrieve a device, its dataframes, and its variables (columns).
#
# It will return  either the nested dict (for multiple devices) or flattened dict (for one device) — the returned structure is exactly how the data is being kept.

# %%
from src.utils import get

# a. View ALL of the loaded data, devices, and device types
# all_data = get(data) # Returns input unchanged (nested dict) 

# b. View loaded data by device type
# print("=== PER TYPE ===")
# atmotube_data = get(data, "Atmotube")
# atmotube_type = get(data, ["Atmotube", "Fitbit"]) 
# print(atmotube_type)

# c. View loaded data by device ID
print("=== PER DEVICE ===")
atmotube_devices = get(data, "Atmotube",
                    ["C7A595F09965_01-May-2026_12-Jun-2026", # flattened dict per device_id 
                    "DB7A737B8CA0_01-May-2026_12-Jun-2026"])
print(atmotube_devices)


# (equivalent manual version, for comparison:)
# atmotube_device = data["Atmotube"]["C3CBE16AE294_01-May-2026_12-Jun-2026"]["data"]
# Out:
# === PER DEVICE ===
# {'C7A595F09965_01-May-2026_12-Jun-2026': {'gis':                        datetime  longitude  latitude      timezone  altitude
# 0     2026-05-30 14:57:00+00:00        NaN       NaN          <NA>       NaN
# 1     2026-05-30 14:58:00+00:00   88.35042  22.50010  Asia/Kolkata       0.0
# 2     2026-05-30 14:59:00+00:00   88.35043  22.50008  Asia/Kolkata       0.0
# 3     2026-05-30 15:00:00+00:00   88.35045  22.50014  Asia/Kolkata       0.0
# 4     2026-05-30 15:01:00+00:00   88.35052  22.50025  Asia/Kolkata       0.0
# ...                         ...        ...       ...           ...       ...
# 11812 2026-06-12 15:52:00+00:00        NaN       NaN          <NA>       NaN
# 11813 2026-06-12 15:53:00+00:00        NaN       NaN          <NA>       NaN
# 11814 2026-06-12 15:54:00+00:00        NaN       NaN          <NA>       NaN
# 11815 2026-06-12 15:55:00+00:00        NaN       NaN          <NA>       NaN
# 11816 2026-06-12 15:56:00+00:00        NaN       NaN          <NA>       NaN
#
# [11817 rows x 5 columns], 'pm':                        datetime  pm1_0_ugm3_atm  pm2_5_ugm3_atm  pm10_ugm3_atm
# 0     2026-05-30 14:57:00+00:00            16.3            17.1           17.1
# 1     2026-05-30 14:58:00+00:00            14.8            15.6           15.6
# 2     2026-05-30 14:59:00+00:00            15.6            16.4           16.4
# 3     2026-05-30 15:00:00+00:00            14.7            15.4           15.4
# 4     2026-05-30 15:01:00+00:00            17.5            18.4           18.4
# ...                         ...             ...             ...            ...
# 11812 2026-06-12 15:52:00+00:00            27.9            29.2           29.2
# 11813 2026-06-12 15:53:00+00:00            28.7            30.1           30.1
# 11814 2026-06-12 15:54:00+00:00            27.2            28.5           28.5
# 11815 2026-06-12 15:55:00+00:00            26.5            27.8           27.8
# 11816 2026-06-12 15:56:00+00:00            26.5            27.9           28.0
#
# [11817 rows x 4 columns], 'weather':                        datetime  aqs_total  temp_c  hum_pct  press_hpa
# 0     2026-05-30 14:57:00+00:00         76    31.5     66.0     1004.0
# 1     2026-05-30 14:58:00+00:00         74    31.6     67.0     1004.0
# 2     2026-05-30 14:59:00+00:00         74    31.5     66.0     1004.1
# 3     2026-05-30 15:00:00+00:00         74    31.5     66.0     1004.1
# 4     2026-05-30 15:01:00+00:00         75    31.4     67.0     1004.7
# ...                         ...        ...     ...      ...        ...
# 11812 2026-06-12 15:52:00+00:00         67    31.3     66.0     1002.5
# 11813 2026-06-12 15:53:00+00:00         66    31.3     67.0     1002.4
# 11814 2026-06-12 15:54:00+00:00         68    31.3     67.0     1002.4
# 11815 2026-06-12 15:55:00+00:00         68    31.3     67.0     1002.4
# 11816 2026-06-12 15:56:00+00:00         68    31.3     66.0     1002.4
#
# [11817 rows x 5 columns], 'gas':                        datetime  tvoc_index  tvoc_ppm  nox_index  co2_ppm
# 0     2026-05-30 14:57:00+00:00        99.0     0.093        1.0    691.0
# 1     2026-05-30 14:58:00+00:00        99.0     0.093        1.0    734.0
# 2     2026-05-30 14:59:00+00:00       102.0     0.095        1.0    727.0
# 3     2026-05-30 15:00:00+00:00       151.0     0.145        1.0    718.0
# 4     2026-05-30 15:01:00+00:00       182.0     0.181        1.0    706.0
# ...                         ...         ...       ...        ...      ...
# 11812 2026-06-12 15:52:00+00:00        77.0     0.071        1.0    504.0
# 11813 2026-06-12 15:53:00+00:00        75.0     0.070        1.0    530.0
# 11814 2026-06-12 15:54:00+00:00        80.0     0.074        1.0    836.0
# 11815 2026-06-12 15:55:00+00:00        81.0     0.076        1.0    646.0
# 11816 2026-06-12 15:56:00+00:00        80.0     0.074        1.0    632.0
#
# [11817 rows x 5 columns], 'phone':                        datetime  battery_phone_pct  motion_phone_bool  \
# 0     2026-05-30 14:57:00+00:00                 24              False
# 1     2026-05-30 14:58:00+00:00                 24               True
# 2     2026-05-30 14:59:00+00:00                 24               True
# 3     2026-05-30 15:00:00+00:00                 24               True
# 4     2026-05-30 15:01:00+00:00                 24               True
# ...                         ...                ...                ...
# 11812 2026-06-12 15:52:00+00:00                 38              False
# 11813 2026-06-12 15:53:00+00:00                 38              False
# 11814 2026-06-12 15:54:00+00:00                 37              False
# 11815 2026-06-12 15:55:00+00:00                 37              False
# 11816 2026-06-12 15:56:00+00:00                 37              False
#
#        gps_phone_bool  charge_phone_bool  cooldown_phone_bool
# 0                <NA>              False                False
# 1                True              False                False
# 2                True              False                False
# 3                True              False                False
# 4                True              False                False
# ...               ...                ...                  ...
# 11812            <NA>              False                False
# 11813            <NA>              False                False
# 11814            <NA>              False                False
# 11815            <NA>              False                False
# 11816            <NA>              False                False
#
# [11817 rows x 6 columns], 'sat':                        datetime  position_error_m
# 0     2026-05-30 14:57:00+00:00               NaN
# 1     2026-05-30 14:58:00+00:00               9.0
# 2     2026-05-30 14:59:00+00:00               7.0
# 3     2026-05-30 15:00:00+00:00               8.0
# 4     2026-05-30 15:01:00+00:00               6.0
# ...                         ...               ...
# 11812 2026-06-12 15:52:00+00:00               NaN
# 11813 2026-06-12 15:53:00+00:00               NaN
# 11814 2026-06-12 15:54:00+00:00               NaN
# 11815 2026-06-12 15:55:00+00:00               NaN
# 11816 2026-06-12 15:56:00+00:00               NaN
#
# [11817 rows x 2 columns], 'txt':                        datetime user_notes
# 0     2026-05-30 14:57:00+00:00        NaN
# 1     2026-05-30 14:58:00+00:00        NaN
# 2     2026-05-30 14:59:00+00:00        NaN
# 3     2026-05-30 15:00:00+00:00        NaN
# 4     2026-05-30 15:01:00+00:00        NaN
# ...                         ...        ...
# 11812 2026-06-12 15:52:00+00:00        NaN
# 11813 2026-06-12 15:53:00+00:00        NaN
# 11814 2026-06-12 15:54:00+00:00        NaN
# 11815 2026-06-12 15:55:00+00:00        NaN
# 11816 2026-06-12 15:56:00+00:00        NaN
#
# [11817 rows x 2 columns]}, 'DB7A737B8CA0_01-May-2026_12-Jun-2026': {'gis':                        datetime  longitude  latitude timezone  altitude
# 0     2026-05-27 12:37:00+00:00        NaN       NaN     <NA>       NaN
# 1     2026-05-27 12:38:00+00:00        NaN       NaN     <NA>       NaN
# 2     2026-05-27 12:39:00+00:00        NaN       NaN     <NA>       NaN
# 3     2026-05-27 12:40:00+00:00        NaN       NaN     <NA>       NaN
# 4     2026-05-27 12:41:00+00:00        NaN       NaN     <NA>       NaN
# ...                         ...        ...       ...      ...       ...
# 17248 2026-06-12 15:51:00+00:00        NaN       NaN     <NA>       NaN
# 17249 2026-06-12 15:52:00+00:00        NaN       NaN     <NA>       NaN
# 17250 2026-06-12 15:53:00+00:00        NaN       NaN     <NA>       NaN
# 17251 2026-06-12 15:54:00+00:00        NaN       NaN     <NA>       NaN
# 17252 2026-06-12 15:55:00+00:00        NaN       NaN     <NA>       NaN
#
# [17253 rows x 5 columns], 'pm':                        datetime  pm1_0_ugm3_atm  pm2_5_ugm3_atm  pm10_ugm3_atm
# 0     2026-05-27 12:37:00+00:00             NaN             NaN            NaN
# 1     2026-05-27 12:38:00+00:00            20.2            21.4           21.4
# 2     2026-05-27 12:39:00+00:00             NaN             NaN            NaN
# 3     2026-05-27 12:40:00+00:00             NaN             NaN            NaN
# 4     2026-05-27 12:41:00+00:00             NaN             NaN            NaN
# ...                         ...             ...             ...            ...
# 17248 2026-06-12 15:51:00+00:00            21.3            22.5           22.5
# 17249 2026-06-12 15:52:00+00:00            21.5            22.7           22.7
# 17250 2026-06-12 15:53:00+00:00            21.5            22.8           22.8
# 17251 2026-06-12 15:54:00+00:00            20.6            21.8           21.8
# 17252 2026-06-12 15:55:00+00:00            21.1            22.3           22.3
#
# [17253 rows x 4 columns], 'weather':                        datetime  aqs_total  temp_c  hum_pct  press_hpa
# 0     2026-05-27 12:37:00+00:00        100     NaN      NaN     1005.4
# 1     2026-05-27 12:38:00+00:00         75     NaN      NaN     1005.4
# 2     2026-05-27 12:39:00+00:00         95     NaN      NaN     1005.4
# 3     2026-05-27 12:40:00+00:00         92     NaN      NaN     1005.4
# 4     2026-05-27 12:41:00+00:00         91     NaN      NaN     1005.3
# ...                         ...        ...     ...      ...        ...
# 17248 2026-06-12 15:51:00+00:00         74     NaN      NaN     1002.5
# 17249 2026-06-12 15:52:00+00:00         73     NaN      NaN     1002.5
# 17250 2026-06-12 15:53:00+00:00         73     NaN      NaN     1002.5
# 17251 2026-06-12 15:54:00+00:00         74     NaN      NaN     1002.5
# 17252 2026-06-12 15:55:00+00:00         74     NaN      NaN     1002.5
#
# [17253 rows x 5 columns], 'gas':                        datetime  tvoc_index  tvoc_ppm  nox_index  co2_ppm
# 0     2026-05-27 12:37:00+00:00         NaN       NaN        NaN      NaN
# 1     2026-05-27 12:38:00+00:00        13.0     0.018        1.0      NaN
# 2     2026-05-27 12:39:00+00:00        51.0     0.049        1.0    386.0
# 3     2026-05-27 12:40:00+00:00        85.0     0.079        1.0    391.0
# 4     2026-05-27 12:41:00+00:00        97.0     0.090        1.0    391.0
# ...                         ...         ...       ...        ...      ...
# 17248 2026-06-12 15:51:00+00:00       101.0     0.094        1.0    565.0
# 17249 2026-06-12 15:52:00+00:00       101.0     0.094        1.0    573.0
# 17250 2026-06-12 15:53:00+00:00       100.0     0.093        1.0    569.0
# 17251 2026-06-12 15:54:00+00:00       100.0     0.093        1.0    579.0
# 17252 2026-06-12 15:55:00+00:00       100.0     0.093        1.0    603.0
#
# [17253 rows x 5 columns], 'phone':                        datetime  battery_phone_pct  motion_phone_bool  \
# 0     2026-05-27 12:37:00+00:00                 88              False
# 1     2026-05-27 12:38:00+00:00                 89              False
# 2     2026-05-27 12:39:00+00:00                 90              False
# 3     2026-05-27 12:40:00+00:00                 90              False
# 4     2026-05-27 12:41:00+00:00                 91              False
# ...                         ...                ...                ...
# 17248 2026-06-12 15:51:00+00:00                 43              False
# 17249 2026-06-12 15:52:00+00:00                 43              False
# 17250 2026-06-12 15:53:00+00:00                 44              False
# 17251 2026-06-12 15:54:00+00:00                 45              False
# 17252 2026-06-12 15:55:00+00:00                 46              False
#
#        gps_phone_bool  charge_phone_bool  cooldown_phone_bool
# 0                <NA>               True                False
# 1                <NA>               True                False
# 2                <NA>               True                False
# 3                <NA>               True                False
# 4                <NA>               True                False
# ...               ...                ...                  ...
# 17248            <NA>               True                False
# 17249            <NA>               True                False
# 17250            <NA>               True                False
# 17251            <NA>               True                False
# 17252            <NA>               True                False
#
# [17253 rows x 6 columns], 'sat':                        datetime  position_error_m
# 0     2026-05-27 12:37:00+00:00               NaN
# 1     2026-05-27 12:38:00+00:00               NaN
# 2     2026-05-27 12:39:00+00:00               NaN
# 3     2026-05-27 12:40:00+00:00               NaN
# 4     2026-05-27 12:41:00+00:00               NaN
# ...                         ...               ...
# 17248 2026-06-12 15:51:00+00:00               NaN
# 17249 2026-06-12 15:52:00+00:00               NaN
# 17250 2026-06-12 15:53:00+00:00               NaN
# 17251 2026-06-12 15:54:00+00:00               NaN
# 17252 2026-06-12 15:55:00+00:00               NaN
#
# [17253 rows x 2 columns], 'txt':                        datetime user_notes
# 0     2026-05-27 12:37:00+00:00        NaN
# 1     2026-05-27 12:38:00+00:00        NaN
# 2     2026-05-27 12:39:00+00:00        NaN
# 3     2026-05-27 12:40:00+00:00        NaN
# 4     2026-05-27 12:41:00+00:00        NaN
# ...                         ...        ...
# 17248 2026-06-12 15:51:00+00:00        NaN
# 17249 2026-06-12 15:52:00+00:00        NaN
# 17250 2026-06-12 15:53:00+00:00        NaN
# 17251 2026-06-12 15:54:00+00:00        NaN
# 17252 2026-06-12 15:55:00+00:00        NaN
#
# [17253 rows x 2 columns]}}

# %%
from src.utils import get

# d. View loaded data by dataframe
print("=== PER DATAFRAME ===")
# get(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", "pm") 
atmotube_df = get(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", ["pm", # flattened per df
                                                                            "weather"])
print(atmotube_df)

print("")
# e. View loaded data by variable
print("=== PER VARIABLE ===")
# get(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", "pm", "pm10_ugm3_atm")
atmotube_col = get(data, "Atmotube", "C7A595F09965_01-May-2026_12-Jun-2026", "pm", ["pm2_5_ugm3_atm", # flattened per col
                                                                                    "pm10_ugm3_atm"])
print(atmotube_col)
# Out:
# === PER DATAFRAME ===
# {'pm':                        datetime  pm1_0_ugm3_atm  pm2_5_ugm3_atm  pm10_ugm3_atm
# 0     2026-05-30 14:57:00+00:00            16.3            17.1           17.1
# 1     2026-05-30 14:58:00+00:00            14.8            15.6           15.6
# 2     2026-05-30 14:59:00+00:00            15.6            16.4           16.4
# 3     2026-05-30 15:00:00+00:00            14.7            15.4           15.4
# 4     2026-05-30 15:01:00+00:00            17.5            18.4           18.4
# ...                         ...             ...             ...            ...
# 11812 2026-06-12 15:52:00+00:00            27.9            29.2           29.2
# 11813 2026-06-12 15:53:00+00:00            28.7            30.1           30.1
# 11814 2026-06-12 15:54:00+00:00            27.2            28.5           28.5
# 11815 2026-06-12 15:55:00+00:00            26.5            27.8           27.8
# 11816 2026-06-12 15:56:00+00:00            26.5            27.9           28.0
#
# [11817 rows x 4 columns], 'weather':                        datetime  aqs_total  temp_c  hum_pct  press_hpa
# 0     2026-05-30 14:57:00+00:00         76    31.5     66.0     1004.0
# 1     2026-05-30 14:58:00+00:00         74    31.6     67.0     1004.0
# 2     2026-05-30 14:59:00+00:00         74    31.5     66.0     1004.1
# 3     2026-05-30 15:00:00+00:00         74    31.5     66.0     1004.1
# 4     2026-05-30 15:01:00+00:00         75    31.4     67.0     1004.7
# ...                         ...        ...     ...      ...        ...
# 11812 2026-06-12 15:52:00+00:00         67    31.3     66.0     1002.5
# 11813 2026-06-12 15:53:00+00:00         66    31.3     67.0     1002.4
# 11814 2026-06-12 15:54:00+00:00         68    31.3     67.0     1002.4
# 11815 2026-06-12 15:55:00+00:00         68    31.3     67.0     1002.4
# 11816 2026-06-12 15:56:00+00:00         68    31.3     66.0     1002.4
#
# [11817 rows x 5 columns]}
#
# === PER VARIABLE ===
# {'pm2_5_ugm3_atm': 0        17.1
# 1        15.6
# 2        16.4
# 3        15.4
# 4        18.4
#          ...
# 11812    29.2
# 11813    30.1
# 11814    28.5
# 11815    27.8
# 11816    27.9
# Name: pm2_5_ugm3_atm, Length: 11817, dtype: float64, 'pm10_ugm3_atm': 0        17.1
# 1        15.6
# 2        16.4
# 3        15.4
# 4        18.4
#          ...
# 11812    29.2
# 11813    30.1
# 11814    28.5
# 11815    27.8
# 11816    28.0
# Name: pm10_ugm3_atm, Length: 11817, dtype: float64}

# %%
from src.utils import get

# Retrieve two or more device ID (flattened dict)
pm2_5_both_devices = get(data, "Atmotube",
                        ["C7A595F09965_01-May-2026_12-Jun-2026",
                        "DB7A737B8CA0_01-May-2026_12-Jun-2026"],
                        "pm", "pm2_5_ugm3_atm")
print(pm2_5_both_devices)
# Out:
# {'C7A595F09965_01-May-2026_12-Jun-2026': 0        17.1
# 1        15.6
# 2        16.4
# 3        15.4
# 4        18.4
#          ...
# 11812    29.2
# 11813    30.1
# 11814    28.5
# 11815    27.8
# 11816    27.9
# Name: pm2_5_ugm3_atm, Length: 11817, dtype: float64, 'DB7A737B8CA0_01-May-2026_12-Jun-2026': 0         NaN
# 1        21.4
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 17248    22.5
# 17249    22.7
# 17250    22.8
# 17251    21.8
# 17252    22.3
# Name: pm2_5_ugm3_atm, Length: 17253, dtype: float64}

# %%
from src.utils import get

# b. Retrieve two or more device ID (flattened dict)
atmotube_two_devices = get(
    data, "Atmotube", 
    ["C7A595F09965_01-May-2026_12-Jun-2026", 
    "DB7A737B8CA0_01-May-2026_12-Jun-2026"], 
    df_key="pm")  
print(atmotube_two_devices)
# Out:
# {'C7A595F09965_01-May-2026_12-Jun-2026': {'pm':                        datetime  pm1_0_ugm3_atm  pm2_5_ugm3_atm  pm10_ugm3_atm
# 0     2026-05-30 14:57:00+00:00            16.3            17.1           17.1
# 1     2026-05-30 14:58:00+00:00            14.8            15.6           15.6
# 2     2026-05-30 14:59:00+00:00            15.6            16.4           16.4
# 3     2026-05-30 15:00:00+00:00            14.7            15.4           15.4
# 4     2026-05-30 15:01:00+00:00            17.5            18.4           18.4
# ...                         ...             ...             ...            ...
# 11812 2026-06-12 15:52:00+00:00            27.9            29.2           29.2
# 11813 2026-06-12 15:53:00+00:00            28.7            30.1           30.1
# 11814 2026-06-12 15:54:00+00:00            27.2            28.5           28.5
# 11815 2026-06-12 15:55:00+00:00            26.5            27.8           27.8
# 11816 2026-06-12 15:56:00+00:00            26.5            27.9           28.0
#
# [11817 rows x 4 columns]}, 'DB7A737B8CA0_01-May-2026_12-Jun-2026': {'pm':                        datetime  pm1_0_ugm3_atm  pm2_5_ugm3_atm  pm10_ugm3_atm
# 0     2026-05-27 12:37:00+00:00             NaN             NaN            NaN
# 1     2026-05-27 12:38:00+00:00            20.2            21.4           21.4
# 2     2026-05-27 12:39:00+00:00             NaN             NaN            NaN
# 3     2026-05-27 12:40:00+00:00             NaN             NaN            NaN
# 4     2026-05-27 12:41:00+00:00             NaN             NaN            NaN
# ...                         ...             ...             ...            ...
# 17248 2026-06-12 15:51:00+00:00            21.3            22.5           22.5
# 17249 2026-06-12 15:52:00+00:00            21.5            22.7           22.7
# 17250 2026-06-12 15:53:00+00:00            21.5            22.8           22.8
# 17251 2026-06-12 15:54:00+00:00            20.6            21.8           21.8
# 17252 2026-06-12 15:55:00+00:00            21.1            22.3           22.3
#
# [17253 rows x 4 columns]}}
